# %%
import pandas as pd
from matplotlib import pyplot as plt
pur=pd.read_csv('D:/dataset/DATASET_LEAD_GENERATION_PURCHASE_MOD.csv')
pur.head(10)
# Out:
#   COUNTRY CITY CITY_DETAILS       NAME      MOBILE  AGE  GENDER_CODE GENDER  \
# 0      IN    D       MUMBAI  EPCYPUIYJ  7044850011   51            0   MALE
# 1      IN    D       MUMBAI  MLGWOVSNU  8712592968   63            0   MALE
# 2      IN    C    BANGALORE  FUAESTLKK  7610555586   64            0   MALE
# 3      IN    A       NAGPUR  UMAFXIRTU  8331385852   70            0   MALE
# 4      IN    D       MUMBAI  KUBLTVBBX  9622263520   20            0   MALE
# 5      IN    B        NASIK  ILBONXYPP  9274487100   33            0   MALE
# 6      IN    C    BANGALORE  LDUBSSVUJ  7077921299   35            0   MALE
# 7      IN    D       MUMBAI  URNCIESQX  9897852928   44            0   MALE
# 8      IN    F      KOLKATA  MQJPMWWRN  7032767111   27            0   MALE
# 9      IN    E         PUNE  KOMRDTGYB  7436473416   66            0   MALE
#
#    INCOME  INCOME_CODE    ...    OWN_CAR  HOUSE_LOAN  CAR_LOAN  SMOKER  \
# ...

# %%
var_names=[key for key in dict(pur.dtypes)]
bp=PdfPages('boxplots purchase data.pdf')
for num in var_names:
    fig,axes=plt.subplots(figsize=(10,4))
    sns.boxplot(y=num,data=pur)
    plt.title(str('box plot of ')+str(num))
    bp.savefig(fig)
bp.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6b06133dfda2> in <module>()
#       3 for num in var_names:
#       4     fig,axes=plt.subplots(figsize=(10,4))
# ----> 5     sns.boxplot(y=num,data=pur)
#       6     plt.title(str('box plot of ')+str(num))
#       7     bp.savefig(fig)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2215     kwargs.update(dict(whis=whis, notch=notch))
#    2216
# -> 2217     plotter.plot(ax, kwargs)
#    2218     return ax
#    2219
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     542     def plot(self, ax, boxplot_kws):
#     543         """Make the plot."""
# --> 544         self.draw_boxplot(ax, boxplot_kws)
# ...

# %%
import pandas_profiling as pf
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas_profiling\plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\Administrator\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Administrator\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Administrator\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
# ...

# %%
pf.ProfileReport(pur)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

# %%
crosstab=pd.crosstab(pur['OTHER_INSURANCE'],pur['PURCHASE'])
crosstab
# Out:
# PURCHASE           0.0  1.0
# OTHER_INSURANCE
# 0                14048  875
# 1                 4914  904

# %%
import pandas as pd
from matplotlib import pyplot as plt
sal=pd.read_csv('D:/dataset/car_sales.csv')
sal.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
# 9          BMW     528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
sal.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
def var_summary(x):
    return pd.Series([x.count(),x.isnull().sum(),x.sum(),x.mean(),x.median(),x.std(),x.var(),x.std()/x.mean(),x.min(),
                     x.dropna().quantile(0.01),x.dropna().quantile(0.05),x.dropna().quantile(0.10),x.dropna().quantile(0.25),
                      x.dropna().quantile(0.50),x.dropna().quantile(0.75),x.dropna().quantile(0.90),x.dropna().quantile(0.95),
                     x.dropna().quantile(0.99),x.max()],
                     index=['N','NMISS','SUM','MEAN','MEDIAN','STD','VAR','CV','MIN',
                                                              'P1','P5','P10','P25','P50','P75','P90','P95','P99','MAX'])

# %%
sal.apply(var_summary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     821         try:
# --> 822             x = float(x)
#     823         except Exception:
#
# ValueError: could not convert string to float: '...-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
sal.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  1
# Length                 1
# Curb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        3
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %%
sal['__year_resale_value']=sal['__year_resale_value'].fillna(sal['__year_resale_value'].mean())


sal['Horsepower']=sal['Horsepower'].fillna(sal['Horsepower'].mean())
sal['Price_in_thousands']=sal['Price_in_thousands'].fillna(sal['Price_in_thousands'].median())

sal['Wheelbase']=sal['Wheelbase'].fillna(sal['Wheelbase'].mean())
sal['Engine_size']=sal['Engine_size'].fillna(sal['Engine_size'].median())

# %%
sal.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919            16.360000    Passenger
# 1        Acura       TL              39.384            19.875000    Passenger
# 2        Acura       CL              14.114            18.225000    Passenger
# 3        Acura       RL               8.588            29.725000    Passenger
# 4         Audi       A4              20.397            22.255000    Passenger
# 5         Audi       A6              18.780            23.555000    Passenger
# 6         Audi       A8               1.380            39.000000    Passenger
# 7          BMW     323i              19.747            18.072975    Passenger
# 8          BMW     328i               9.231            28.675000    Passenger
# 9          BMW     528i              17.527            36.125000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
var_names=[key for key in dict(sal.dtypes)]
bp=PdfPages('boxplots purchase data.pdf')
for num in var_names:
    fig,axes=plt.subplots(figsize=(10,4))
    sns.boxplot(y=num,data=pur)
    plt.title(str('box plot of ')+str(num))
    bp.savefig(fig)
bp.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-cef3b1ce4752> in <module>()
#       3 for num in var_names:
#       4     fig,axes=plt.subplots(figsize=(10,4))
# ----> 5     sns.boxplot(y=num,data=pur)
#       6     plt.title(str('box plot of ')+str(num))
#       7     bp.savefig(fig)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2209     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2210                           orient, color, palette, saturation,
# -> 2211                           width, dodge, fliersize, linewidth)
#    2212
#    2213     if ax is None:
#
# ...
