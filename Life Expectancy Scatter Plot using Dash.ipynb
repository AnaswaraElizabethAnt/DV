# %%
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# %%
life = pd.read_csv('D:/dataset/Life Expectancy Data.csv')

# %%
life.head()
# Out:
#        Country  Year      Status  Life_expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#      ...      Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
life.Year.unique()
# Out:
# array([2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003, 2002, 2001, 2000], dtype=int64)

# %%
life.describe()
# Out:
#               Year  Life_expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
app = dash.Dash()

app.layout = html.Div([ # this Div is the main Div containing all charts and html components
    html.H1('Life Expectancy Dashboard',
           style={'textAlign': 'center',
                  'color': 'green'
        }),
    html.Div([html.H5("Level"),
        dcc.Slider(id='slider_input',
            min=2000,
            max=2015,
            step=1,
            value=2000,
            marks={i: '{}'.format(i) for i in [2000,2001,2002,2003,2004,2005,2006,2007,
                                                    2008,2009,2010,2011,2012,2013,2014,2015]},
        ),
    ],style={'height': '100','width':'90%','paddingLeft':'30px'}),
    dcc.Graph(
        id='my_scatter',
        animate=True
    )
])

@app.callback(Output('my_scatter', 'figure'),
             [Input('slider_input', 'value')])

def update_plot(slider_input):
    life_year = life[life['Year']==slider_input]
    trace1 = go.Scatter(
        x = life_year[life_year['Status']=='Developing']['Life expectancy '],
        y = life_year[life_year['Status']=='Developing']['GDP'],
        mode = 'markers',
        name = 'Developing',
        marker = dict(
            size = 13,
            color = 'lightgreen'
        )
    )
    trace2 = go.Scatter(
        x = life_year[life_year['Status']=='Developed']['Life expectancy '],
        y = life_year[life_year['Status']=='Developed']['GDP'],
        mode = 'markers',
        name = 'Developed',
        marker = dict(
            size = 13,
            color = 'pink'
        )
    )
    data = [trace1,trace2]
    
    return {
        'data': data,
        'layout': go.Layout(
            autosize=False,
            title='Scatter plot',
            hovermode='closest',
            yaxis=dict(zeroline=False, range=[-10000,50000]),
        )
            
    }

# %%
if __name__ == '__main__':
    app.run_server()
# Out:
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Dec/2018 15:40:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 15:40:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 15:40:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 15:40:34] "GET /favicon.ico HTTP/1.1" 200 -
# [2018-12-17 15:40:34,674] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 3063, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas\_libs\index.pyx", line 140, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 162, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1492, in pandas._libs.hashtable.PyObjectHashTable.get_item
# ...

# %%
## With Styling
app = dash.Dash()

app.layout = html.Div([ # this Div is the main Div containing all charts and html components
    html.H1('Life Expectancy Dashboard',
           style={'textAlign': 'center',
                  'color': 'green'
        }),
    html.Div([html.H5("Level"),
        dcc.Slider(id='slider_input',
            min=2000,
            max=2015,
            step=1,
            value=2000,
            marks={i: '{}'.format(i) for i in [2000,2001,2002,2003,2004,2005,2006,2007,
                                                    2008,2009,2010,2011,2012,2013,2014,2015]},
        ),
    ],style={'height': '100','width':'90%'}),
    dcc.Graph(
        id='my_scatter',
        animate=True
    )
],style={'backgroundColor':'#FFFFCC'})

@app.callback(Output('my_scatter', 'figure'),
             [Input('slider_input', 'value')])

def update_plot(slider_input):
    life_year = life[life['Year']==slider_input]
    trace1 = go.Scatter(
        x = life_year[life_year['Status']=='Developing']['Life expectancy '],
        y = life_year[life_year['Status']=='Developing']['GDP'],
        mode = 'markers',
        name = 'Developing',
        marker = dict(
            size = 12,
            color = 'green'
        )
    )
    trace2 = go.Scatter(
        x = life_year[life_year['Status']=='Developed']['Life expectancy '],
        y = life_year[life_year['Status']=='Developed']['GDP'],
        mode = 'markers',
        name = 'Developed',
        marker = dict(
            size = 12,
            color = 'red'
        )
    )
    data = [trace1,trace2]
    
    return {
        'data': data,
        'layout': go.Layout(
            autosize=False,
            title='Scatter plot',
            hovermode='closest',
            plot_bgcolor='#FFFF99',
            paper_bgcolor='#FFFF99',
            yaxis=dict(zeroline=False, range=[-10000,50000]),
            )
            
        }

# %%
if __name__ == '__main__':
    app.run_server()
# Out:
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Dec/2018 11:07:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:16] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:16] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2018 11:07:25] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
